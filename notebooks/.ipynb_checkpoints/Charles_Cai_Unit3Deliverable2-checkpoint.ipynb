# %% [markdown]
# # Telco Customer Churn Analysis
#
# ## Business Context
# This project investigates customer churn for a telecommunications company.
# The goal is to build a machine learning model to predict churn risk and
# segment customers to support marketing and customer communication strategies.
